# %% [markdown]
# # This file is for numpy
# numpy = numerical python

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.4.0

# %%
# my_list = [1, 2, 3, 4, 5]


# array = np.array(my_list)
# print(array)
# print(type(array))
# arrayt = array * 2
# print(arrayt)
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# [ 2  4  6  8 10]

# %%
#WORKING WITH MULTIDIMENSIONAL ARRAY

array = np.array([['A', 'B', 'C'], #-- THIS IS AN EXAMPLE OF 2D ARRAY WITH ROWS AND COLUMN
                  ['D', 'E', 'F'],
                  ['G', 'H', 'I']]
                )

print(array.ndim)
# Out:
# 2
